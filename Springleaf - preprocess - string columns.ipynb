# %% [markdown]
# ## Import useful stuff and define ancillary functions

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from __future__ import division

from collections import defaultdict, namedtuple
from datetime import datetime, timedelta
from functools import partial
import inspect
import json
import os
import re
import sys
import cPickle as pickle

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder


def analyze_str_columns(cols, df, only_percent=False):
    print 'Total samples: %s' % len(df)

    for c in cols:
        print '##############################'
        VAR_df = df[[c, 'target']]
        unique_vals = VAR_df[c].unique()
        # NaNs are the only floats among the values
        non_nan = [v for v in unique_vals if type(v) == str]
        str_0 = []
        str_1 = []
        col_names = []
        for u in unique_vals:
            if type(u) == str:
                col_mask = (VAR_df[c] == u)
            else:
                col_mask = VAR_df[c].isnull()
            str_0.append(len(VAR_df[col_mask & (VAR_df['target'] == 0)]))
            str_1.append(len(VAR_df[col_mask & (VAR_df['target'] == 1)]))

            col_names.append('%s_%s'%(c,u))
        VAR_df_counts = pd.DataFrame([str_0, str_1],
                                     columns=col_names,
                                     index=pd.Index([0, 1], name='target'))
        if not only_percent:
            print "------Counts-------"
            print VAR_df_counts
        print "----Percentages----"
        print VAR_df_counts/VAR_df_counts.sum()*100
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# # Load train data
# Using pandas' read_csv with all the defaults

# %%
if os.name == 'nt':
    TRAIN_PATH = r'D:\train.csv'
    PTRAIN_PATH = r'D:\train_preprocessed_float_string.csv'
    TEST_PATH = r'D:\test.csv'
    GOOGNEWS_PATH = r'D:\GoogleNews-vectors-negative300.bin.gz'
    VOCAB_PATH = r'D:\big.txt'
else:
    TRAIN_PATH = r'/media/mtambos/speedy/train.csv'
    PTRAIN_PATH = r'/media/mtambos/speedy/train_preprocessed_float_string.csv'
    TEST_PATH = r'/media/mtambos/speedy/test.csv'
    GOOGNEWS_PATH = r'/media/mtambos/speedy/GoogleNews-vectors-negative300.bin.gz'
    VOCAB_PATH = r'/media/mtambos/speedy/big.txt'
df = pd.read_csv(PTRAIN_PATH, index_col="ID")
# Out:
# /home/mtambos/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (8,9,10,11,12,23,137,173,186,194,197,198,200,204,207) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %% [markdown]
# ### Define columns

# %%
str_cols = [u'VAR_0001', u'VAR_0005', u'VAR_0044',
            u'VAR_0200', u'VAR_0202', u'VAR_0214',
            u'VAR_0216', u'VAR_0222', u'VAR_0237',
            u'VAR_0274', u'VAR_0283', u'VAR_0305',
            u'VAR_0325', u'VAR_0342', u'VAR_0352',
            u'VAR_0353', u'VAR_0354', u'VAR_0404',
            u'VAR_0466', u'VAR_0467', u'VAR_0493',
            u'VAR_1934']
try:
    str_cols = [c for c in str_cols if c in df.columns and df[c].dtype==np.object]
except NameError:
    pass

# %% [markdown]
# # See if the classes are skewed

# %%
neg_samples_count = len(df['target'][df['target']==0])
pos_samples_count = len(df['target'][df['target']==1])
print '%s negative samples; %.2f%% of total' % (neg_samples_count, neg_samples_count/len(df)*100)
print '%s positive samples; %.2f%% of total' % (pos_samples_count, pos_samples_count/len(df)*100)
# Out:
# 111458 negative samples; 76.75% of total
# 33773 positive samples; 23.25% of total

# %% [markdown]
# ## Cast string columns as string and make 'null' data uniform (instead of nan, -1, [], etc.)

# %%
def filter_str(str_cell):
    str_cell = re.sub(r'[\W_]+', ' ', str(str_cell))
    str_cell = str_cell.strip().lower()
    if str_cell in ('1', '-1', '[]', 'nan', ''):
        return None
    else:
        return str_cell

df[str_cols] = df[str_cols].astype(np.str).applymap(filter_str)
df[str_cols]
# Out:
#        VAR_0001 VAR_0005 VAR_0044           VAR_0200      VAR_0202 VAR_0214  \
# ID
# 2             h        c     None      ft lauderdale  batchinquiry     None
# 4             h        b     None             santee  batchinquiry     None
# 5             h        c     None         reedsville  batchinquiry     None
# 7             h        c     None            liberty  batchinquiry     None
# 8             r        n     None          frankfort  batchinquiry     None
# 14            r        c     None             spring  batchinquiry     None
# 16            h        c     None            gresham  batchinquiry     None
# 20            r        b     None      warner robins  batchinquiry     None
# 21            r        n     None        san antonio  batchinquiry     None
# 22            r        n     None         norristown  batchinquiry     None
# 23            r        c     None       murfreesboro  batchinquiry     None
# 24            h        c     None       cartersville  batchinquiry     None
# 25            h        b     None          bethlehem  batchinquiry     None
# 26            r        b     None         gig harbor  batchinquiry     None
# 28            q        b     None        bakersfield  batchinquiry     None
# 30            r        b     None            herndon  batchinquiry     None
# 31            h        c     None         shelby gap  batchinquiry     None
# 32            r        n     None            ontario  batchinquiry     None
# 35            h        c     None            memphis  batchinquiry     None
# 36            r        b     None         bakersfied  batchinquiry     None
# 37            r        b     None  altamonte springs  batchinquiry     None
# 38            h        b     None        barnesville  batchinquiry     None
# 40            h        b     None            houston  batchinquiry     None
# 42            r        n     None               peru  batchinquiry     None
# 43            r        b     None             tacoma  batchinquiry     None
# 46            r        c     None              ozark  batchinquiry     None
# 50            r        c     None          riverside  batchinquiry     None
# 51            r        b     None            augusta  batchinquiry     None
# 52            r        b     None            chicago  batchinquiry     None
# 54            r        b     None        sevierville  batchinquiry     None
# ...         ...      ...      ...                ...           ...      ...
# 290409        h        n     None         las cruces  batchinquiry     None
# 290412        r        c     None       martinsville  batchinquiry     None
# 290414        r        s     None        bakersfield  batchinquiry     None
# 290415        r        c     None           la porte  batchinquiry     None
# 290417        r        s     None       newport news  batchinquiry     None
# 290424        h        b     None          englewood  batchinquiry     None
# 290426        h        c     None           warfield  batchinquiry     None
# 290427        h        c     None             malden  batchinquiry     None
# 290429        r        b     None           marietta  batchinquiry     None
# 290431        r        c     None           prospect  batchinquiry     None
# 290432        r        c     None       olive branch  batchinquiry     None
# 290434        r        b     None          san diego  batchinquiry     None
# 290436        h        b     None        summerville  batchinquiry     None
# 290439        r        b     None              alice  batchinquiry     None
# 290440        r        c     None          pittsvile  batchinquiry     None
# 290441        r        b     None          nashville  batchinquiry     None
# 290443        r        b     None            wyncote  batchinquiry     None
# 290445        r        c     None       indianapolis  batchinquiry     None
# 290447        r        c     None           lagrande  batchinquiry     None
# 290448        r        c     None           commerce  batchinquiry     None
# 290449        r        b     None         thornville  batchinquiry     None
# 290450        r        n     None      new braunfels  batchinquiry     None
# 290452        h        b     None             bethel  batchinquiry     None
# 290453        r        b     None       indianapolis  batchinquiry     None
# 290454        r        n     None               katy  batchinquiry     None
# 290457        h        c     None          lafayette  batchinquiry     None
# 290458        r        c     None            gardena  batchinquiry     None
# 290459        r        b     None             covina  batchinquiry     None
# 290461        h        c     None            batavia  batchinquiry     None
# 290463        h        b     None       sherman oaks  batchinquiry     None
#
#        VAR_0216 VAR_0222 VAR_0237 VAR_0274   ...    VAR_0325 VAR_0342  \
# ID                                           ...
# 2            ds       c6       fl       fl   ...        None       cf
# 4            ds       c6       ca       mi   ...           h       ec
# 5            ds       c6       wv       wv   ...           r       uu
# 7            ds       c6       tx       tx   ...           h     None
# 8            ds       c6       il       il   ...           s     None
# 14           ds       c6       tx       me   ...           h       fe
# 16           ds       c6       or       ca   ...           s       dc
# 20           ds       c6       ga       sc   ...           s       ff
# 21           ds       c6       tx       tx   ...           s     None
# 22           ds       c6       pa       pa   ...           s       ee
# 23           ds       c6       tn       tn   ...           h       fe
# 24           ds       c6       ga       ga   ...           s     None
# 25           ds       c6       pa       pa   ...           s     None
# 26           ds       c6       wa       ca   ...           s       bc
# 28           ds       c6       ca       ca   ...           s     None
# 30           ds       c6       va       va   ...           h       fe
# 31           ds       c6       ky       ky   ...           s     None
# 32           ds       c6       ca       al   ...           h       ee
# 35           ds       c6       tn       tn   ...           s       fe
# 36           ds       c6       ca       ca   ...           h       ff
# 37           ds       c6       fl       nc   ...           h       ef
# 38           ds       c6       pa       pa   ...           r       fd
# 40           ds       c6       tx       tx   ...           s       ff
# 42           ds       c6       in       in   ...           s       ff
# 43           ds       c6       wa       ga   ...           s       ee
# 46           ds       c6       mo       mo   ...           s       uu
# 50           ds       c6       ca       ca   ...        None     None
# 51           ds       c6       ga       ga   ...           s       ff
# 52           ds       c6       il       mn   ...           h       ed
# 54           ds       c6       tn       mi   ...           s       dd
# ...         ...      ...      ...      ...   ...         ...      ...
# 290409       ds       c6       nm       il   ...           s       ff
# 290412       ds       c6       in       fl   ...           f       ce
# 290414       ds       c6       ca       ca   ...           s     None
# 290415       ds       c6       in       in   ...           h       fe
# 290417       ds       c6       va       md   ...           s       fe
# 290424       ds       c6       tn       tn   ...           s       ff
# 290426       ds       c6       va       va   ...           s       uu
# 290427       ds       c6       mo       mo   ...           s     None
# 290429       ds       c6       ga       ct   ...           p       dd
# 290431       ds       c6       oh       oh   ...           h       fe
# 290432       ds       c6       ms       ms   ...           h       ff
# 290434       ds       c6       ca       tx   ...           h       ed
# 290436       ds       c6       ga       ga   ...           s       ff
# 290439       ds       c6       tx       tx   ...           p       uu
# 290440       ds       c6       va       va   ...           h       fd
# 290441       ds       c6       nc       nc   ...           h       fe
# 290443       ds       c6       pa       pa   ...        None       dc
# 290445       ds       c6       in       in   ...           s       ef
# 290447       ds       c6       or       pa   ...           s       dd
# 290448       ds       c6       tx       tx   ...        None       ff
# 290449       ds       c6       oh       oh   ...           s     None
# 290450       ds       c6       tx       tx   ...           s       dd
# 290452       ds       c6       oh       oh   ...           p       ff
# 290453       ds       c6       in       il   ...           h       ff
# 290454       ds       c6       tx       tx   ...           s       dd
# 290457       ds       c6       la       la   ...           s     None
# 290458       ds       c6       ca       ca   ...           s       be
# 290459       ds       c6       ca       ca   ...           p       cc
# 290461       ds       c6       oh     None   ...        None     None
# 290463       ds       c6       ca       ca   ...        None     None
#
#        VAR_0352 VAR_0353 VAR_0354                 VAR_0404 VAR_0466  \
# ID
# 2             o        u        o  chief executive officer     None
# 4             o        r        r                     None        i
# 5             r        r     None                     None     None
# 7             r        r     None                     None     None
# 8             r        u        o                     None     None
# 14            u        r        r                     None     None
# 16            o        o        o                     None     None
# 20            u        o        r                     None     None
# 21            r        u        u                     None     None
# 22            u        u        u                     None     None
# 23            o        r        r                     None     None
# 24            r        o        u                     None        i
# 25            u        o        u                     None        i
# 26            u        u        o                     None     None
# 28            r        o        u                     None     None
# 30            r        r        u                     None     None
# 31            r        o        o                     None     None
# 32            r        r        r                     None     None
# 35            o        u        u                     None     None
# 36            u        r        u                     None     None
# 37            r        r        u                     None     None
# 38            o        r        u                     None        i
# 40            u        u        u                    conta     None
# 42            u        u     None                     None     None
# 43            r        u     None                     None     None
# 46            r        u     None                     None     None
# 50            o     None     None                     None     None
# 51            u        u        u                     None     None
# 52            r        r        o                  contact     None
# 54            u        u        u                     None     None
# ...         ...      ...      ...                      ...      ...
# 290409        r        o     None                     None     None
# 290412        r        r     None                     None        i
# 290414        u        u        u                     None     None
# 290415        u        r        u                     None        i
# 290417        u        u        r                     None     None
# 290424        o        o        o                     None     None
# 290426        u        o        r                     None        i
# 290427        u        u        r                     None     None
# 290429        u        r        u                     None     None
# 290431        o        r        o                     None     None
# 290432        r        r        u                     None     None
# 290434        u        r        u                     None     None
# 290436        u        o        r                     None        i
# 290439        u        r        r                     None     None
# 290440        u        r        u                     None     None
# 290441        u        r        u                     None     None
# 290443        o        u        u                secretary     None
# 290445        u        u        u                     None     None
# 290447        u        u        u                     None        i
# 290448        o        u        r                  contact     None
# 290449        u        o        r                     None     None
# 290450        u        u        u                     None     None
# 290452        o        r        u                     None     None
# 290453        u        r     None                     None     None
# 290454        u        u        o                     None     None
# 290457        r        u        r                     None     None
# 290458        r        u        r                     None        i
# 290459        u        r     None                     None     None
# 290461     None     None     None                     None     None
# 290463     None     None     None                     None     None
#
#           VAR_0467                       VAR_0493 VAR_1934
# ID
# 2             None  community association manager     iaps
# 4       discharged                           None     iaps
# 5             None                           None     iaps
# 7             None                           None      rcc
# 8             None                           None   branch
# 14            None                           None     iaps
# 16            None                           None     iaps
# 20            None                           None     iaps
# 21            None                           None   mobile
# 22            None                           None   branch
# 23            None                           None   branch
# 24       dismissed                           None   branch
# 25      discharged                           None     iaps
# 26            None                           None   branch
# 28            None                           None     iaps
# 30            None                           None     iaps
# 31            None                           None   branch
# 32            None                           None     iaps
# 35            None                           None     iaps
# 36            None                           None   branch
# 37            None                           None     iaps
# 38      discharged                           None   branch
# 40            None                           None     iaps
# 42            None                           None   branch
# 43            None                           None     iaps
# 46            None                           None     iaps
# 50            None                           None   branch
# 51            None                           None     iaps
# 52            None                           None     iaps
# 54            None                           None   branch
# ...            ...                            ...      ...
# 290409        None                           None   branch
# 290412  discharged                           None     iaps
# 290414        None                           None   branch
# 290415  discharged                           None   branch
# 290417        None                           None   branch
# 290424        None                           None   branch
# 290426  discharged                     nurse aide   branch
# 290427        None                           None     iaps
# 290429        None                           None     iaps
# 290431        None                           None     iaps
# 290432        None                           None   branch
# 290434        None                           None   branch
# 290436   dismissed                           None     iaps
# 290439        None                           None   branch
# 290440        None                           None   branch
# 290441        None                           None     iaps
# 290443        None                           None   branch
# 290445        None                           None   branch
# 290447  discharged                           None     iaps
# 290448        None                           None     iaps
# 290449        None                           None     iaps
# 290450        None                           None     iaps
# 290452        None                           None   branch
# 290453        None                           None     iaps
# 290454        None                           None     iaps
# 290457        None                           None   branch
# 290458  discharged                           None     iaps
# 290459        None                           None   branch
# 290461        None                           None     iaps
# 290463        None                           None     iaps
#
# [145231 rows x 22 columns]

# %% [markdown]
# # Vectorize String and Datetime colums

# %% [markdown]
# ## String columns

# %% [markdown]
# ### See how many different values the string columns have

# %%
str_desc = df[str_cols].describe()
str_desc = pd.DataFrame(str_desc, columns=sorted(str_desc.columns, key=lambda c: str_desc.loc['std', c]))
str_desc
# Out:
#             VAR_0214       VAR_0005       VAR_0467       VAR_0353  \
# count  145231.000000  145231.000000  145231.000000  145231.000000
# mean        0.000537       0.662001       0.321880       2.182723
# std         0.066898       0.755864       0.756309       0.918042
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       1.000000
# 50%         0.000000       1.000000       0.000000       2.000000
# 75%         0.000000       1.000000       0.000000       3.000000
# max        12.000000       3.000000       3.000000       3.000000
#
#             VAR_0352       VAR_0001       VAR_1934       VAR_0354  \
# count  145231.000000  145231.000000  145231.000000  145231.000000
# mean        2.008228       1.172580       1.125985       2.015279
# std         0.928806       0.983218       1.096356       1.123611
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       1.000000
# 50%         2.000000       2.000000       2.000000       2.000000
# 75%         3.000000       2.000000       2.000000       3.000000
# max         3.000000       2.000000       4.000000       3.000000
#
#             VAR_0283       VAR_0305       VAR_0325       VAR_0237  \
# count  145231.000000  145231.000000  145231.000000  145231.000000
# mean        4.273241       5.047738       5.362078      23.839256
# std         1.432471       1.739619       2.385425      13.322850
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000       5.000000       3.000000      11.000000
# 50%         5.000000       6.000000       7.000000      26.000000
# 75%         5.000000       6.000000       7.000000      36.000000
# max         6.000000       7.000000       8.000000      45.000000
#
#             VAR_0342       VAR_0274       VAR_0493       VAR_0404  \
# count  145231.000000  145231.000000  145231.000000  145231.000000
# mean       26.243385      27.826828      20.664059      75.749227
# std        15.853942      16.728497      87.876039     278.754038
# min         0.000000       0.000000       0.000000       0.000000
# 25%        17.000000      12.000000       0.000000       0.000000
# 50%        32.000000      28.000000       0.000000       0.000000
# 75%        40.000000      41.000000       0.000000       0.000000
# max        49.000000      56.000000     602.000000    1787.000000
#
#            VAR_0200
# count  145231.00000
# mean     5948.37755
# std      3487.11275
# min         0.00000
# 25%      2804.00000
# 50%      5894.00000
# 75%      8983.00000
# max     12275.00000

# %% [markdown]
# Column VAR_0044 has not a single value, drop it.

# %%
df.drop('VAR_0044', axis=1, inplace=True)
str_cols.remove('VAR_0044')

# %% [markdown]
# ### Columns VAR_0202, VAR_0216, VAR_0222 and VAR_0466 have only one value. Check if there's some correlation between the values and the target.

# %% [markdown]
# #### Replace their string values for 1 if there was something in the cell, or 0 if there wasn't.

# %%
analyze_str_columns(['VAR_0202', 'VAR_0216', 'VAR_0222', 'VAR_0466'], df)
# Out:
# Total samples: 145231
# ##############################
# ------Counts-------
#         VAR_0202_batchinquiry  VAR_0202_None
# target
# 0                      111415             43
# 1                       33760             13
# ----Percentages----
#         VAR_0202_batchinquiry  VAR_0202_None
# target
# 0                   76.745307      76.785714
# 1                   23.254693      23.214286
# ##############################
# ------Counts-------
#         VAR_0216_ds  VAR_0216_None
# target
# 0            111415             43
# 1             33760             13
# ----Percentages----
#         VAR_0216_ds  VAR_0216_None
# target
# 0         76.745307      76.785714
# 1         23.254693      23.214286
# ##############################
# ------Counts-------
#         VAR_0222_c6  VAR_0222_None
# target
# 0            111415             43
# 1             33760             13
# ----Percentages----
#         VAR_0222_c6  VAR_0222_None
# target
# 0         76.745307      76.785714
# 1         23.254693      23.214286
# ##############################
# ------Counts-------
#         VAR_0466_None  VAR_0466_i
# target
# 0               94671       16787
# 1               27708        6065
# ----Percentages----
#         VAR_0466_None  VAR_0466_i
# target
# 0           77.358861   73.459653
# 1           22.641139   26.540347

# %% [markdown]
# The values of these columns seem to be distributed according to the same distribution in the target column, so they're useless.

# %%
cols = ['VAR_0202', 'VAR_0216', 'VAR_0222', 'VAR_0466']
df.drop(cols, axis=1, inplace=True)
for c in cols:
    str_cols.remove(c)
del cols

# %% [markdown]
# ### Encode the labels of the rest of the columns

# %%
encoder = LabelEncoder()
for col in str_cols:
    df[col] = encoder.fit_transform(df[col])

# %% [markdown]
# # Save preprocessed data to another csv file

# %%
df.to_csv(PTRAIN_PATH)

# %%
with open('deleted_str_cols.pickle', 'wb') as fp:
    pickle.dump(['VAR_0044', 'VAR_0202', 'VAR_0216', 'VAR_0222', 'VAR_0466'], fp)
